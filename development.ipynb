# %%
from pyspark.sql import functions as F

path = "/Workspace/Users/bogdanovici.robert@gmail.com/opsfleet-project/data/videos.csv"

videos_df = (
    spark.read
        .option("header", "true")
        .csv(path)
)

videos_df.write.format("delta").mode("overwrite").saveAsTable("staging.videos")

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS staging")

# %%
dbutils.library.restartPython()

# %%
spark.sql("DROP TABLE IF EXISTS staging.users")
spark.sql("DROP TABLE IF EXISTS staging.events")
spark.sql("DROP TABLE IF EXISTS staging.videos")
spark.sql("DROP TABLE IF EXISTS intermediate.user_sessions")
spark.sql("DROP TABLE IF EXISTS mart.fact_user_session")

# %%
from pyspark.sql import SparkSession

from staging import run_staging
from intermediate import run_intermediate
from mart import run_mart

def main():
    spark = SparkSession.builder.getOrCreate()
    run_staging(spark)
    run_intermediate(spark)
    run_mart(spark)
if __name__ == "__main__":
    main()
